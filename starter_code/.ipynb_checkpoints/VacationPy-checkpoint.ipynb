# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\glori\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\glori\anaconda3\lib\site-packages (from gmaps) (5.0.5)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\glori\anaconda3\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\glori\anaconda3\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: six in c:\users\glori\anaconda3\lib\site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\glori\anaconda3\lib\site-packages (from gmaps) (7.19.0)
# Requirement already satisfied: ipython-genutils in c:\users\glori\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\glori\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\glori\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\glori\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.8)
# Requirement already satisfied: jedi>=0.10 in c:\users\glori\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.17.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\glori\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.8)
# Requirement already satisfied: pygments in c:\users\glori\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.7.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\glori\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (50.3.1.post20201107)
# Requirement already satisfied: pickleshare in c:\users\glori\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: backcall in c:\users\glori\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: decorator in c:\users\glori\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\glori\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\glori\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.4)
# Requirement already satisfied: tornado>=4.2 in c:\users\glori\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.4)
# Requirement already satisfied: jupyter-client in c:\users\glori\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.7)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\glori\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\glori\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.3)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\glori\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\glori\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\glori\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.1)
# Requirement already satisfied: prometheus-client in c:\users\glori\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\glori\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\glori\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: Send2Trash in c:\users\glori\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\glori\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (19.0.2)
# Requirement already satisfied: jinja2 in c:\users\glori\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\glori\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\glori\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\glori\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\glori\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\glori\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\glori\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.3)
# Requirement already satisfied: defusedxml in c:\users\glori\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\glori\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\glori\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\glori\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\glori\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\glori\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: bleach in c:\users\glori\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.2.1)
# Requirement already satisfied: testpath in c:\users\glori\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\glori\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: pycparser in c:\users\glori\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: async-generator in c:\users\glori\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\glori\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: packaging in c:\users\glori\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.4)
# Requirement already satisfied: webencodings in c:\users\glori\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\glori\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_df=pd.read_csv("City_Weather.csv").drop("Unnamed: 0", axis=1)
city_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      yellowknife  62.4560 -114.3525    272.15        64          75
# 1        esperance -33.8667  121.9000    285.15        94          40
# 2     punta arenas -53.1500  -70.9167    277.15       100          90
# 3          brovary  50.5000   30.7667    294.26        45           0
# 4    makakilo city  21.3469 -158.0858    296.15        68           1
# ..             ...      ...       ...       ...       ...         ...
# 545     solnechnyy  50.7214  136.6319    274.31        86          90
# 546          minna   9.6139    6.5569    306.15        49          20
# 547     surovikino  48.6078   42.8486    284.98        85         100
# 548      kavaratti  10.5669   72.6420    303.02        72          10
# 549      manokwari  -0.8667  134.0833    300.13        77         100
#
#      Wind Speed Country        Date
# 0          5.14      CA  1619780343
# 1          2.57      AU  1619780358
# 2          5.14      CL  1619780358
# 3          8.00      UA  1619780359
# 4          2.57      US  1619780359
# ..          ...     ...         ...
# 545        2.77      RU  1619780524
# 546        4.63      NG  1619780239
# 547        3.79      RU  1619780231
# 548        3.15      IN  1619780524
# 549        2.93      ID  1619780524
#
# [550 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
import gmaps
gmaps.configure(api_key=g_key)

#Store 'Lat' and 'Lng' into  locations 
locations = city_df[["Lat", "Lng"]].astype(float)

#Convert humidity to float and store
humidity=city_df["Humidity"].astype(float)

#Heatmap
fig=gmaps.figure(center =[0,0], zoom_level = 2)

#Heat layer
heat_layer=gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=100, point_radius=1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Cities to fit weather conditions
city_weather_df = city_df[(city_df['Max Temp'] >= 70) & (city_df['Max Temp']) <= 80]
city_weather_df = city_df[city_df['Wind Speed'] <= 10]
city_weather_df = city_df[city_df['Cloudiness'] == 0]
city_weather_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3          brovary  50.5000   30.7667    294.26        45           0
# 34  guerrero negro  27.9769 -114.0611    289.47        77           0
# 46   mar del plata -38.0023  -57.5575    287.04        93           0
# 49            aksu  41.1231   80.2644    304.29         4           0
# 64           kutum  14.2000   24.6667    307.16        12           0
#
#     Wind Speed Country        Date
# 3         8.00      UA  1619780359
# 34        2.86      MX  1619780367
# 46        3.60      AR  1619780370
# 49        4.73      CN  1619780370
# 64        5.11      SD  1619780374

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#Create Hotel Name Column
hotel_df=city_weather_df.loc[:,['City', 'Country', 'Lat', 'Lng']]
hotel_df['Hotel Name'] = ''
hotel_df.head()
# Out:
#               City Country      Lat       Lng Hotel Name
# 3          brovary      UA  50.5000   30.7667
# 34  guerrero negro      MX  27.9769 -114.0611
# 46   mar del plata      AR -38.0023  -57.5575
# 49            aksu      CN  41.1231   80.2644
# 64           kutum      SD  14.2000   24.6667

# %%
#parameters
params = {'type': 'hotel',
          'radius':5000, 
          'keyword': 'hotel',
          'key': g_key
         }

for index, row in hotel_df.iterrows():
    lat = row['Lat']
    lng = row['Lng']
   
    #change location each iteration while leaving original params in place
    params['location'] = f'{lat},{lng}'
    
    #Use base_url
    base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
    
    #Make request and print url
    hotel_response = requests.get(base_url, params=params).json()
   
    try:             
        hotel_df.loc[index, 'Hotel Name'] = hotel_response['results'][0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
hotel_df.head()
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
#               City Country      Lat       Lng           Hotel Name
# 3          brovary      UA  50.5000   30.7667    Grand Sport Hotel
# 34  guerrero negro      MX  27.9769 -114.0611  Hotel Los Caracoles
# 46   mar del plata      AR -38.0023  -57.5575      Hotel Las Rocas
# 49            aksu      CN  41.1231   80.2644        Jianshe Hotel
# 64           kutum      SD  14.2000   24.6667

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
